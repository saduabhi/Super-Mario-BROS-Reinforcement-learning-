# %%
pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.8.0-cp38-cp38-win_amd64.whl (438.0 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.25.0-cp38-cp38-win_amd64.whl (1.5 MB)
# Collecting flatbuffers>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.15.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
# Collecting libclang>=9.0.1
#   Downloading libclang-14.0.1-py2.py3-none-win_amd64.whl (14.2 MB)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (2.10.0)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (52.0.0.post20210125)
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.46.1-cp38-cp38-win_amd64.whl (3.5 MB)
# Collecting gast>=0.2.1
#   Downloading gast-0.5.3-py3-none-any.whl (19 kB)
# Requirement already satisfied: numpy>=1.20 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.20.1)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting absl-py>=0.4.0
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (3.7.4.3)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.20.1-cp38-cp38-win_amd64.whl (904 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.36.2)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (1.0.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.6.6-py2.py3-none-any.whl (156 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu) (2.25.1)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.11.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow-gpu) (3.4.1)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu) (2.10)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=430b59c518575daf06c23e8f4d365e783e3817b18f71733ba76258d74b6fdf9a
#   Stored in directory: c:\users\computing\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built termcolor
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, importlib-metadata, google-auth, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, tf-estimator-nightly, termcolor, tensorflow-io-gcs-filesystem, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow-gpu
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.10.0
#     Uninstalling importlib-metadata-3.10.0:
#       Successfully uninstalled importlib-metadata-3.10.0
# Successfully installed absl-py-1.0.0 astunparse-1.6.3 cachetools-5.0.0 flatbuffers-2.0 gast-0.5.3 google-auth-2.6.6 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.46.1 importlib-metadata-4.11.3 keras-2.8.0 keras-preprocessing-1.1.2 libclang-14.0.1 markdown-3.3.7 oauthlib-3.2.0 opt-einsum-3.3.0 protobuf-3.20.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.8 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-gpu-2.8.0 tensorflow-io-gcs-filesystem-0.25.0 termcolor-1.1.0 tf-estimator-nightly-2.8.0.dev2021122109
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Installing the game**

# %%
# !pip install gym_super_mario_bros==7.3.0 nes_py
# Out:
# Collecting gym_super_mario_bros==7.3.0
#   Downloading gym_super_mario_bros-7.3.0-py2.py3-none-any.whl (198 kB)
# Collecting nes_py
#   Downloading nes_py-8.1.8.tar.gz (76 kB)
# Collecting gym>=0.17.2
#   Downloading gym-0.23.1.tar.gz (626 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (1.20.1)
# Collecting pyglet<=1.5.11,>=1.4.0
#   Downloading pyglet-1.5.11-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: tqdm>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (4.59.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gym>=0.17.2->nes_py) (1.6.0)
# Collecting gym-notices>=0.0.4
#   Downloading gym_notices-0.0.6-py3-none-any.whl (2.7 kB)
# Requirement already satisfied: importlib-metadata>=4.10.0 in c:\programdata\anaconda3\lib\site-packages (from gym>=0.17.2->nes_py) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.10.0->gym>=0.17.2->nes_py) (3.4.1)
# Building wheels for collected packages: nes-py, gym
#   Building wheel for nes-py (setup.py): started
#   Building wheel for nes-py (setup.py): finished with status 'done'
#   Created wheel for nes-py: filename=nes_py-8.1.8-cp38-cp38-win_amd64.whl size=47358 sha256=fbb4d882a6545fbf4d458295385422f35a999224d5dc59964699d1664baca1e0
#   Stored in directory: c:\users\computing\appdata\local\pip\cache\wheels\8d\6e\f0\113c979eba40def28ee9b3c81a4adec00386106d81fb3bc2c2
#   Building wheel for gym (PEP 517): started
#   Building wheel for gym (PEP 517): finished with status 'done'
#   Created wheel for gym: filename=gym-0.23.1-py3-none-any.whl size=701357 sha256=c27a6d7345922245b774c0dcf00a64fb6eb8be0d3bf5b23c8a6ed0352f2b195d
#   Stored in directory: c:\users\computing\appdata\local\pip\cache\wheels\78\28\77\b0c74e80a2a4faae0161d5c53bc4f8e436e77aedc79136ee13
# Successfully built nes-py gym
# Installing collected packages: gym-notices, pyglet, gym, nes-py, gym-super-mario-bros
# Successfully installed gym-0.23.1 gym-notices-0.0.6 gym-super-mario-bros-7.3.0 nes-py-8.1.8 pyglet-1.5.11

# %% [markdown]
# **Importing the libraries**

# %%
# Importing the game
import gym_super_mario_bros
# Importing the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# Importing the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
import os

from torchvision import transforms
import gym
from gym.spaces import Box
import gym_super_mario_bros
import numpy as np
import torch
from gym.wrappers import FrameStack
from nes_py.wrappers import JoypadSpace
from torch import nn
from torch.distributions import Categorical
import matplotlib.pyplot as plt
device = torch.device("cuda")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class SkipFrame(gym.Wrapper):
    def __init__(self, env, skip):
        super().__init__(env)
        self._skip = skip

    def step(self, action):
        total_reward = 0.0
        done = False
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            total_reward += reward
            if done:
                break
        return obs, total_reward, done, info
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Grayscaling for observation**

# %%
class GrayScaleObservation(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = Box(low=0, high=255, shape=self.observation_space.shape[:2], dtype=np.uint8)

    def observation(self, observation):
        transform = transforms.Grayscale()
        return transform(torch.tensor(np.transpose(observation, (2, 0, 1)).copy(), dtype=torch.float))

# %% [markdown]
# **Resizing the observation**

# %%
class ResizeObservation(gym.ObservationWrapper):
    def __init__(self, env, shape):
        super().__init__(env)
        self.shape = (shape, shape)
        obs_shape = self.shape + self.observation_space.shape[2:]
        self.observation_space = Box(low=0, high=255, shape=obs_shape, dtype=np.uint8)

    def observation(self, observation):
        transformations = transforms.Compose([transforms.Resize(self.shape), transforms.Normalize(0, 255)])
        return transformations(observation).squeeze(0)


env = gym_super_mario_bros.make('SuperMarioBros-1-1-v0')
env = JoypadSpace(env, [["right"], ["right", "A"]])
env = FrameStack(ResizeObservation(GrayScaleObservation(SkipFrame(env, skip=4)), shape=84), num_stack=4)
env.seed(64)
env.action_space.seed(64)
torch.manual_seed(64)
torch.random.manual_seed(64)
np.random.seed(64)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gym\envs\registration.py:505: UserWarning: WARN: The environment SuperMarioBros-1-1-v0 is out of date. You should consider upgrading to version `v3` with the environment ID `SuperMarioBros-1-1-v3`.
#   logger.warn(

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.actor = nn.Sequential(
            nn.Conv2d(in_channels=4, out_channels=32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, env.action_space.n)
        )
        self.critic = nn.Sequential(
            nn.Conv2d(in_channels=4, out_channels=32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, 1)
        )

    def forward(self, obs):
        return Categorical(logits=self.actor(obs)), self.critic(obs).reshape(-1)

# %%
class PPOSolver:
    def __init__(self):
        self.rewards = []
        self.gamma = 0.95
        self.lamda = 0.95
        self.worker_steps = 4096
        self.n_mini_batch = 4
        self.epochs = 30
        self.save_directory = r"C:\Users\Computing\Desktop\PPO without baseline seed 64"
        self.batch_size = self.worker_steps
        self.mini_batch_size = self.batch_size // self.n_mini_batch
        self.obs = env.reset().__array__()
        self.policy = Model().to(device)
        self.mse_loss = nn.MSELoss()
        self.optimizer = torch.optim.Adam([
            {'params': self.policy.actor.parameters(), 'lr': 0.00025},
            {'params': self.policy.critic.parameters(), 'lr': 0.001}
        ], eps=1e-4)
        self.policy_old = Model().to(device)
        self.policy_old.load_state_dict(self.policy.state_dict())
        self.all_episode_rewards = []
        self.all_mean_rewards = []
        self.episode = 0

    def save_checkpoint(self):
        filename = os.path.join(self.save_directory, 'checkpoint_{}.pth'.format(self.episode))
        torch.save(self.policy_old.state_dict(), f=filename)
        print('Checkpoint saved to \'{}\''.format(filename))

    def load_checkpoint(self, filename):
        self.policy.load_state_dict(torch.load(os.path.join(self.save_directory, filename)))
        self.policy_old.load_state_dict(torch.load(os.path.join(self.save_directory, filename)))
        print('Resuming training from checkpoint \'{}\'.'.format(filename))

    def sample(self):
        rewards = np.zeros(self.worker_steps, dtype=np.float32)
        actions = np.zeros(self.worker_steps, dtype=np.int32)
        done = np.zeros(self.worker_steps, dtype=bool)
        obs = np.zeros((self.worker_steps, 4, 84, 84), dtype=np.float32)
        log_pis = np.zeros(self.worker_steps, dtype=np.float32)
        values = np.zeros(self.worker_steps, dtype=np.float32)
        for t in range(self.worker_steps):
            with torch.no_grad():
                obs[t] = self.obs
                pi, v = self.policy_old(torch.tensor(self.obs, dtype=torch.float32, device=device).unsqueeze(0))
                values[t] = v.cpu().numpy()
                a = pi.sample()
                actions[t] = a.cpu().numpy()
                log_pis[t] = pi.log_prob(a).cpu().numpy()
            self.obs, rewards[t], done[t], _ = env.step(actions[t])
            self.obs = self.obs.__array__()
            env.render()
            self.rewards.append(rewards[t])
            if done[t]:
                self.episode += 1
                self.all_episode_rewards.append(np.sum(self.rewards))
                self.rewards = []
                env.reset()
                if self.episode % 10 == 0:
                    print('Episode: {}, average reward: {}'.format(self.episode, np.mean(self.all_episode_rewards[-10:])))
                    self.all_mean_rewards.append(np.mean(self.all_episode_rewards[-10:]))
                    plt.plot(self.all_mean_rewards)
                    plt.savefig("{}/mean_reward_{}.png".format(self.save_directory, self.episode))
                    plt.clf()
                    self.save_checkpoint()
        returns, advantages = self.calculate_advantages(done, rewards, values)
        return {
            'obs': torch.tensor(obs.reshape(obs.shape[0], *obs.shape[1:]), dtype=torch.float32, device=device),
            'actions': torch.tensor(actions, device=device),
            'values': torch.tensor(values, device=device),
            'log_pis': torch.tensor(log_pis, device=device),
            'advantages': torch.tensor(advantages, device=device, dtype=torch.float32),
            'returns': torch.tensor(returns, device=device, dtype=torch.float32)
        }

    def calculate_advantages(self, done, rewards, values):
        _, last_value = self.policy_old(torch.tensor(self.obs, dtype=torch.float32, device=device).unsqueeze(0))
        last_value = last_value.cpu().data.numpy()
        values = np.append(values, last_value)
        returns = []
        gae = 0
        for i in reversed(range(len(rewards))):
            mask = 1.0 - done[i]
            delta = rewards[i] + self.gamma * values[i + 1] * mask - values[i]
            gae = delta + self.gamma * self.lamda * mask * gae
            returns.insert(0, gae + values[i])
        adv = np.array(returns) - values[:-1]
        return returns, (adv - np.mean(adv)) / (np.std(adv) + 1e-8)

    def train(self, samples, clip_range):
        indexes = torch.randperm(self.batch_size)
        for start in range(0, self.batch_size, self.mini_batch_size):
            end = start + self.mini_batch_size
            mini_batch_indexes = indexes[start: end]
            mini_batch = {}
            for k, v in samples.items():
                mini_batch[k] = v[mini_batch_indexes]
            for _ in range(self.epochs):
                loss = self.calculate_loss(clip_range=clip_range, samples=mini_batch)
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()
            self.policy_old.load_state_dict(self.policy.state_dict())

    def calculate_loss(self, samples, clip_range):
        sampled_returns = samples['returns']
        sampled_advantages = samples['advantages']
        pi, value = self.policy(samples['obs'])
        ratio = torch.exp(pi.log_prob(samples['actions']) - samples['log_pis'])
        clipped_ratio = ratio.clamp(min=1.0 - clip_range, max=1.0 + clip_range)
        policy_reward = torch.min(ratio * sampled_advantages, clipped_ratio * sampled_advantages)
        entropy_bonus = pi.entropy()
        vf_loss = self.mse_loss(value, sampled_returns)
        loss = -policy_reward + 0.5 * vf_loss - 0.01 * entropy_bonus
        return loss.mean()

# %% [markdown]
# **Using PPO agent as solver**

# %%
solver = PPOSolver()
while True:
    solver.train(solver.sample(), 0.2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# Episode: 10, average reward: 600.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_10.pth'
# Episode: 20, average reward: 681.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_20.pth'
# Episode: 30, average reward: 735.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_30.pth'
# Episode: 40, average reward: 546.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_40.pth'
# Episode: 50, average reward: 580.2000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_50.pth'
# Episode: 60, average reward: 753.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_60.pth'
# Episode: 70, average reward: 796.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_70.pth'
# Episode: 80, average reward: 715.2000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_80.pth'
# Episode: 90, average reward: 829.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_90.pth'
# Episode: 100, average reward: 831.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_100.pth'
# Episode: 110, average reward: 747.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_110.pth'
# Episode: 120, average reward: 712.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_120.pth'
# Episode: 130, average reward: 659.7000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_130.pth'
# Episode: 140, average reward: 591.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_140.pth'
# Episode: 150, average reward: 550.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_150.pth'
# Episode: 160, average reward: 728.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_160.pth'
# Episode: 170, average reward: 710.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_170.pth'
# Episode: 180, average reward: 452.3999938964844
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_180.pth'
# Episode: 190, average reward: 761.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_190.pth'
# Episode: 200, average reward: 630.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_200.pth'
# Episode: 210, average reward: 652.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_210.pth'
# Episode: 220, average reward: 723.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_220.pth'
# Episode: 230, average reward: 768.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_230.pth'
# Episode: 240, average reward: 682.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_240.pth'
# Episode: 250, average reward: 695.7000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_250.pth'
# Episode: 260, average reward: 675.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_260.pth'
# Episode: 270, average reward: 702.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_270.pth'
# Episode: 280, average reward: 765.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_280.pth'
# Episode: 290, average reward: 777.7000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_290.pth'
# Episode: 300, average reward: 998.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_300.pth'
# Episode: 310, average reward: 599.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_310.pth'
# Episode: 320, average reward: 746.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_320.pth'
# Episode: 330, average reward: 863.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_330.pth'
# Episode: 340, average reward: 599.7000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_340.pth'
# Episode: 350, average reward: 598.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_350.pth'
# Episode: 360, average reward: 781.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_360.pth'
# Episode: 370, average reward: 790.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_370.pth'
# Episode: 380, average reward: 655.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_380.pth'
# Episode: 390, average reward: 734.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_390.pth'
# Episode: 400, average reward: 597.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_400.pth'
# Episode: 410, average reward: 837.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_410.pth'
# Episode: 420, average reward: 930.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_420.pth'
# Episode: 430, average reward: 971.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_430.pth'
# Episode: 440, average reward: 830.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_440.pth'
# Episode: 450, average reward: 877.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_450.pth'
# Episode: 460, average reward: 865.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_460.pth'
# Episode: 470, average reward: 618.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_470.pth'
# Episode: 480, average reward: 825.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_480.pth'
# Episode: 490, average reward: 629.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_490.pth'
# Episode: 500, average reward: 886.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_500.pth'
# Episode: 510, average reward: 747.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_510.pth'
# Episode: 520, average reward: 913.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_520.pth'
# Episode: 530, average reward: 1014.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_530.pth'
# Episode: 540, average reward: 814.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_540.pth'
# Episode: 550, average reward: 994.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_550.pth'
# Episode: 560, average reward: 915.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_560.pth'
# Episode: 570, average reward: 533.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_570.pth'
# Episode: 580, average reward: 842.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_580.pth'
# Episode: 590, average reward: 831.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_590.pth'
# Episode: 600, average reward: 641.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_600.pth'
# Episode: 610, average reward: 927.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_610.pth'
# Episode: 620, average reward: 748.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_620.pth'
# Episode: 630, average reward: 988.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_630.pth'
# Episode: 640, average reward: 861.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_640.pth'
# Episode: 650, average reward: 752.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_650.pth'
# Episode: 660, average reward: 752.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_660.pth'
# Episode: 670, average reward: 941.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_670.pth'
# Episode: 680, average reward: 725.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_680.pth'
# Episode: 690, average reward: 898.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_690.pth'
# Episode: 700, average reward: 767.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_700.pth'
# Episode: 710, average reward: 1023.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_710.pth'
# Episode: 720, average reward: 1052.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_720.pth'
# Episode: 730, average reward: 847.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_730.pth'
# Episode: 740, average reward: 943.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_740.pth'
# Episode: 750, average reward: 673.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_750.pth'
# Episode: 760, average reward: 809.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_760.pth'
# Episode: 770, average reward: 861.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_770.pth'
# Episode: 780, average reward: 918.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_780.pth'
# Episode: 790, average reward: 882.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_790.pth'
# Episode: 800, average reward: 804.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_800.pth'
# Episode: 810, average reward: 910.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_810.pth'
# Episode: 820, average reward: 650.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_820.pth'
# Episode: 830, average reward: 709.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_830.pth'
# Episode: 840, average reward: 824.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_840.pth'
# Episode: 850, average reward: 1001.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_850.pth'
# Episode: 860, average reward: 776.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_860.pth'
# Episode: 870, average reward: 736.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_870.pth'
# Episode: 880, average reward: 698.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_880.pth'
# Episode: 890, average reward: 909.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_890.pth'
# Episode: 900, average reward: 757.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_900.pth'
# Episode: 910, average reward: 1041.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_910.pth'
# Episode: 920, average reward: 1005.2000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_920.pth'
# Episode: 930, average reward: 740.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_930.pth'
# Episode: 940, average reward: 689.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_940.pth'
# Episode: 950, average reward: 983.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_950.pth'
# Episode: 960, average reward: 998.7000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_960.pth'
# Episode: 970, average reward: 1020.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_970.pth'
# Episode: 980, average reward: 937.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_980.pth'
# Episode: 990, average reward: 881.2000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_990.pth'
# Episode: 1000, average reward: 1079.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1000.pth'
# Episode: 1010, average reward: 1135.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1010.pth'
# Episode: 1020, average reward: 859.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1020.pth'
# Episode: 1030, average reward: 1050.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1030.pth'
# Episode: 1040, average reward: 906.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1040.pth'
# Episode: 1050, average reward: 814.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1050.pth'
# Episode: 1060, average reward: 1159.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1060.pth'
# Episode: 1070, average reward: 1110.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1070.pth'
# Episode: 1080, average reward: 734.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1080.pth'
# Episode: 1090, average reward: 727.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1090.pth'
# Episode: 1100, average reward: 943.2000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1100.pth'
# Episode: 1110, average reward: 920.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1110.pth'
# Episode: 1120, average reward: 846.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1120.pth'
# Episode: 1130, average reward: 1150.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1130.pth'
# Episode: 1140, average reward: 816.7000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1140.pth'
# Episode: 1150, average reward: 1142.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1150.pth'
# Episode: 1160, average reward: 1043.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1160.pth'
# Episode: 1170, average reward: 1078.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1170.pth'
# Episode: 1180, average reward: 1077.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1180.pth'
# Episode: 1190, average reward: 804.7000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1190.pth'
# Episode: 1200, average reward: 959.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1200.pth'
# Episode: 1210, average reward: 1223.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1210.pth'
# Episode: 1220, average reward: 907.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1220.pth'
# Episode: 1230, average reward: 1159.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1230.pth'
# Episode: 1240, average reward: 989.2000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1240.pth'
# Episode: 1250, average reward: 1032.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1250.pth'
# Episode: 1260, average reward: 1074.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1260.pth'
# Episode: 1270, average reward: 1205.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1270.pth'
# Episode: 1280, average reward: 853.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1280.pth'
# Episode: 1290, average reward: 1160.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1290.pth'
# Episode: 1300, average reward: 1139.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1300.pth'
# Episode: 1310, average reward: 1385.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1310.pth'
# Episode: 1320, average reward: 1123.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1320.pth'
# Episode: 1330, average reward: 1434.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1330.pth'
# Episode: 1340, average reward: 1125.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1340.pth'
# Episode: 1350, average reward: 1447.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1350.pth'
# Episode: 1360, average reward: 1093.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1360.pth'
# Episode: 1370, average reward: 1067.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1370.pth'
# Episode: 1380, average reward: 777.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1380.pth'
# Episode: 1390, average reward: 1347.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1390.pth'
# Episode: 1400, average reward: 1272.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1400.pth'
# Episode: 1410, average reward: 1197.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1410.pth'
# Episode: 1420, average reward: 1252.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1420.pth'
# Episode: 1430, average reward: 1426.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1430.pth'
# Episode: 1440, average reward: 1242.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1440.pth'
# Episode: 1450, average reward: 1161.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1450.pth'
# Episode: 1460, average reward: 1573.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1460.pth'
# Episode: 1470, average reward: 1221.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1470.pth'
# Episode: 1480, average reward: 1477.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1480.pth'
# Episode: 1490, average reward: 1231.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1490.pth'
# Episode: 1500, average reward: 1038.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1500.pth'
# Episode: 1510, average reward: 1708.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1510.pth'
# Episode: 1520, average reward: 1395.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1520.pth'
# Episode: 1530, average reward: 1559.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1530.pth'
# Episode: 1540, average reward: 1116.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1540.pth'
# Episode: 1550, average reward: 1228.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1550.pth'
# Episode: 1560, average reward: 1302.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1560.pth'
# Episode: 1570, average reward: 1111.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1570.pth'
# Episode: 1580, average reward: 1264.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1580.pth'
# Episode: 1590, average reward: 1302.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1590.pth'
# Episode: 1600, average reward: 1035.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1600.pth'
# Episode: 1610, average reward: 926.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1610.pth'
# Episode: 1620, average reward: 1372.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1620.pth'
# Episode: 1630, average reward: 1043.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1630.pth'
# Episode: 1640, average reward: 1498.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1640.pth'
# Episode: 1650, average reward: 1858.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1650.pth'
# Episode: 1660, average reward: 1782.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1660.pth'
# Episode: 1670, average reward: 1672.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1670.pth'
# Episode: 1680, average reward: 2095.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1680.pth'
# Episode: 1690, average reward: 2327.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1690.pth'
# Episode: 1700, average reward: 2113.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1700.pth'
# Episode: 1710, average reward: 2456.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1710.pth'
# Episode: 1720, average reward: 2775.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1720.pth'
# Episode: 1730, average reward: 2584.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1730.pth'
# Episode: 1740, average reward: 2456.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1740.pth'
# Episode: 1750, average reward: 2494.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1750.pth'
# Episode: 1760, average reward: 2135.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1760.pth'
# Episode: 1770, average reward: 2143.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1770.pth'
# Episode: 1780, average reward: 2401.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1780.pth'
# Episode: 1790, average reward: 2477.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1790.pth'
# Episode: 1800, average reward: 2859.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1800.pth'
# Episode: 1810, average reward: 2473.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1810.pth'
# Episode: 1820, average reward: 2987.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1820.pth'
# Episode: 1830, average reward: 1934.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1830.pth'
# Episode: 1840, average reward: 2320.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1840.pth'
# Episode: 1850, average reward: 2759.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1850.pth'
# Episode: 1860, average reward: 2086.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1860.pth'
# Episode: 1870, average reward: 2501.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1870.pth'
# Episode: 1880, average reward: 2753.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1880.pth'
# Episode: 1890, average reward: 2776.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1890.pth'
# Episode: 1900, average reward: 2975.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1900.pth'
# Episode: 1910, average reward: 2834.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1910.pth'
# Episode: 1920, average reward: 2517.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1920.pth'
# Episode: 1930, average reward: 2919.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1930.pth'
# Episode: 1940, average reward: 1548.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1940.pth'
# Episode: 1950, average reward: 1776.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1950.pth'
# Episode: 1960, average reward: 1871.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1960.pth'
# Episode: 1970, average reward: 2203.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1970.pth'
# Episode: 1980, average reward: 1755.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1980.pth'
# Episode: 1990, average reward: 1618.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_1990.pth'
# Episode: 2000, average reward: 1911.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2000.pth'
# Episode: 2010, average reward: 1540.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2010.pth'
# Episode: 2020, average reward: 1227.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2020.pth'
# Episode: 2030, average reward: 1730.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2030.pth'
# Episode: 2040, average reward: 1169.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2040.pth'
# Episode: 2050, average reward: 1122.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2050.pth'
# Episode: 2060, average reward: 1649.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2060.pth'
# Episode: 2070, average reward: 1979.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2070.pth'
# Episode: 2080, average reward: 2214.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2080.pth'
# Episode: 2090, average reward: 1868.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2090.pth'
# Episode: 2100, average reward: 2602.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2100.pth'
# Episode: 2110, average reward: 2664.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2110.pth'
# Episode: 2120, average reward: 2435.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2120.pth'
# Episode: 2130, average reward: 2499.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2130.pth'
# Episode: 2140, average reward: 2535.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2140.pth'
# Episode: 2150, average reward: 2075.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2150.pth'
# Episode: 2160, average reward: 1191.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2160.pth'
# Episode: 2170, average reward: 886.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2170.pth'
# Episode: 2180, average reward: 827.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2180.pth'
# Episode: 2190, average reward: 831.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2190.pth'
# Episode: 2200, average reward: 675.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2200.pth'
# Episode: 2210, average reward: 687.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2210.pth'
# Episode: 2220, average reward: 1179.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2220.pth'
# Episode: 2230, average reward: 1502.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2230.pth'
# Episode: 2240, average reward: 977.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2240.pth'
# Episode: 2250, average reward: 1216.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2250.pth'
# Episode: 2260, average reward: 1034.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2260.pth'
# Episode: 2270, average reward: 929.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2270.pth'
# Episode: 2280, average reward: 942.7999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2280.pth'
# Episode: 2290, average reward: 947.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2290.pth'
# Episode: 2300, average reward: 1064.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2300.pth'
# Episode: 2310, average reward: 1041.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2310.pth'
# Episode: 2320, average reward: 782.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2320.pth'
# Episode: 2330, average reward: 966.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2330.pth'
# Episode: 2340, average reward: 1177.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2340.pth'
# Episode: 2350, average reward: 1227.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2350.pth'
# Episode: 2360, average reward: 1299.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2360.pth'
# Episode: 2370, average reward: 1191.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2370.pth'
# Episode: 2380, average reward: 876.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2380.pth'
# Episode: 2390, average reward: 1011.2999877929688
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2390.pth'
# Episode: 2400, average reward: 1549.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2400.pth'
# Episode: 2410, average reward: 1021.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2410.pth'
# Episode: 2420, average reward: 1132.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2420.pth'
# Episode: 2430, average reward: 1234.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2430.pth'
# Episode: 2440, average reward: 1304.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2440.pth'
# Episode: 2450, average reward: 1047.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2450.pth'
# Episode: 2460, average reward: 1403.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2460.pth'
# Episode: 2470, average reward: 1250.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2470.pth'
# Episode: 2480, average reward: 1488.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2480.pth'
# Episode: 2490, average reward: 1426.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2490.pth'
# Episode: 2500, average reward: 1555.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2500.pth'
# Episode: 2510, average reward: 1473.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2510.pth'
# Episode: 2520, average reward: 1501.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2520.pth'
# Episode: 2530, average reward: 1521.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2530.pth'
# Episode: 2540, average reward: 1909.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2540.pth'
# Episode: 2550, average reward: 1927.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2550.pth'
# Episode: 2560, average reward: 1606.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2560.pth'
# Episode: 2570, average reward: 1109.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2570.pth'
# Episode: 2580, average reward: 1384.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2580.pth'
# Episode: 2590, average reward: 1333.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2590.pth'
# Episode: 2600, average reward: 2029.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2600.pth'
# Episode: 2610, average reward: 1990.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2610.pth'
# Episode: 2620, average reward: 1637.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2620.pth'
# Episode: 2630, average reward: 1440.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2630.pth'
# Episode: 2640, average reward: 1699.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2640.pth'
# Episode: 2650, average reward: 1716.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2650.pth'
# Episode: 2660, average reward: 1720.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2660.pth'
# Episode: 2670, average reward: 1077.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2670.pth'
# Episode: 2680, average reward: 2181.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2680.pth'
# Episode: 2690, average reward: 2563.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2690.pth'
# Episode: 2700, average reward: 2262.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2700.pth'
# Episode: 2710, average reward: 2496.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2710.pth'
# Episode: 2720, average reward: 2845.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2720.pth'
# Episode: 2730, average reward: 2782.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2730.pth'
# Episode: 2740, average reward: 2494.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2740.pth'
# Episode: 2750, average reward: 2574.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2750.pth'
# Episode: 2760, average reward: 2531.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2760.pth'
# Episode: 2770, average reward: 2168.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2770.pth'
# Episode: 2780, average reward: 2573.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2780.pth'
# Episode: 2790, average reward: 2627.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2790.pth'
# Episode: 2800, average reward: 1968.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2800.pth'
# Episode: 2810, average reward: 1167.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2810.pth'
# Episode: 2820, average reward: 2699.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2820.pth'
# Episode: 2830, average reward: 1920.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2830.pth'
# Episode: 2840, average reward: 2146.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2840.pth'
# Episode: 2850, average reward: 2099.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2850.pth'
# Episode: 2860, average reward: 2454.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2860.pth'
# Episode: 2870, average reward: 2172.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2870.pth'
# Episode: 2880, average reward: 2041.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2880.pth'
# Episode: 2890, average reward: 2139.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2890.pth'
# Episode: 2900, average reward: 869.2000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2900.pth'
# Episode: 2910, average reward: 1165.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2910.pth'
# Episode: 2920, average reward: 1323.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2920.pth'
# Episode: 2930, average reward: 1272.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2930.pth'
# Episode: 2940, average reward: 1720.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2940.pth'
# Episode: 2950, average reward: 2059.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2950.pth'
# Episode: 2960, average reward: 2671.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2960.pth'
# Episode: 2970, average reward: 2909.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2970.pth'
# Episode: 2980, average reward: 2647.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2980.pth'
# Episode: 2990, average reward: 2920.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_2990.pth'
# Episode: 3000, average reward: 2815.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3000.pth'
# Episode: 3010, average reward: 2924.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3010.pth'
# Episode: 3020, average reward: 2899.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3020.pth'
# Episode: 3030, average reward: 3030.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3030.pth'
# Episode: 3040, average reward: 2783.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3040.pth'
# Episode: 3050, average reward: 2886.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3050.pth'
# Episode: 3060, average reward: 2969.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3060.pth'
# Episode: 3070, average reward: 2036.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3070.pth'
# Episode: 3080, average reward: 2587.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3080.pth'
# Episode: 3090, average reward: 1948.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3090.pth'
# Episode: 3100, average reward: 1242.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3100.pth'
# Episode: 3110, average reward: 1136.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3110.pth'
# Episode: 3120, average reward: 812.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3120.pth'
# Episode: 3130, average reward: 913.2000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3130.pth'
# Episode: 3140, average reward: 812.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3140.pth'
# Episode: 3150, average reward: 812.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3150.pth'
# Episode: 3160, average reward: 812.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3160.pth'
# Episode: 3170, average reward: 812.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3170.pth'
# Episode: 3180, average reward: 812.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3180.pth'
# Episode: 3190, average reward: 1318.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3190.pth'
# Episode: 3200, average reward: 1746.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3200.pth'
# Episode: 3210, average reward: 510.8999938964844
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3210.pth'
# Episode: 3220, average reward: 231.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3220.pth'
# Episode: 3230, average reward: 1607.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3230.pth'
# Episode: 3240, average reward: 2411.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3240.pth'
# Episode: 3250, average reward: 1406.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3250.pth'
# Episode: 3260, average reward: 2049.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3260.pth'
# Episode: 3270, average reward: 2682.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3270.pth'
# Episode: 3280, average reward: 2824.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3280.pth'
# Episode: 3290, average reward: 3027.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3290.pth'
# Episode: 3300, average reward: 1787.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3300.pth'
# Episode: 3310, average reward: 1006.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3310.pth'
# Episode: 3320, average reward: 1088.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3320.pth'
# Episode: 3330, average reward: 811.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3330.pth'
# Episode: 3340, average reward: 1724.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3340.pth'
# Episode: 3350, average reward: 2893.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3350.pth'
# Episode: 3360, average reward: 2950.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3360.pth'
# Episode: 3370, average reward: 2929.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3370.pth'
# Episode: 3380, average reward: 2971.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3380.pth'
# Episode: 3390, average reward: 2890.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3390.pth'
# Episode: 3400, average reward: 2410.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3400.pth'
# Episode: 3410, average reward: 2410.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3410.pth'
# Episode: 3420, average reward: 2433.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3420.pth'
# Episode: 3430, average reward: 2183.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3430.pth'
# Episode: 3440, average reward: 2960.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3440.pth'
# Episode: 3450, average reward: 2938.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3450.pth'
# Episode: 3460, average reward: 3028.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3460.pth'
# Episode: 3470, average reward: 2843.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3470.pth'
# Episode: 3480, average reward: 2995.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3480.pth'
# Episode: 3490, average reward: 2929.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3490.pth'
# Episode: 3500, average reward: 3028.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3500.pth'
# Episode: 3510, average reward: 2962.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3510.pth'
# Episode: 3520, average reward: 2654.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3520.pth'
# Episode: 3530, average reward: 2403.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3530.pth'
# Episode: 3540, average reward: 2897.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3540.pth'
# Episode: 3550, average reward: 2682.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3550.pth'
# Episode: 3560, average reward: 1675.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3560.pth'
# Episode: 3570, average reward: 1594.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3570.pth'
# Episode: 3580, average reward: 1442.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3580.pth'
# Episode: 3590, average reward: 1674.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3590.pth'
# Episode: 3600, average reward: 1501.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3600.pth'
# Episode: 3610, average reward: 954.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3610.pth'
# Episode: 3620, average reward: 1821.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3620.pth'
# Episode: 3630, average reward: 1022.7000122070312
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3630.pth'
# Episode: 3640, average reward: 1188.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3640.pth'
# Episode: 3650, average reward: 1209.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3650.pth'
# Episode: 3660, average reward: 1591.4000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3660.pth'
# Episode: 3670, average reward: 1926.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3670.pth'
# Episode: 3680, average reward: 1938.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO without baseline seed 64\checkpoint_3680.pth'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0093ac6b592a> in <module>
#       1 solver = PPOSolver()
#       2 while True:
# ----> 3     solver.train(solver.sample(), 0.2)
#
# <ipython-input-9-415e7dc82870> in sample(self)
#      43             with torch.no_grad():
#      44                 obs[t] = self.obs
# ---> 45                 pi, v = self.policy_old(torch.tensor(self.obs, dtype=torch.float32, device=device).unsqueeze(0))
#      46                 values[t] = v.cpu().numpy()
#      47                 a = pi.sample()
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-8-bc84f63b3787> in forward(self, obs)
#      28
#      29     def forward(self, obs):
# ---> 30         return Categorical(logits=self.actor(obs)), self.critic(obs).reshape(-1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
# --> 443         return self._conv_forward(input, self.weight, self.bias)
#     444
#     445 class Conv3d(_ConvNd):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py in _conv_forward(self, input, weight, bias)
#     437                             weight, bias, self.stride,
#     438                             _pair(0), self.dilation, self.groups)
# --> 439         return F.conv2d(input, weight, bias, self.stride,
#     440                         self.padding, self.dilation, self.groups)
#     441
#
# KeyboardInterrupt:
